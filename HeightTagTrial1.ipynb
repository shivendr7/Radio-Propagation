# %% [markdown]
# <a href="https://colab.research.google.com/github/shivendr7/Radio-Propagation/blob/main/HeightTagTrial1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install osmnx

# %%
import osmnx as ox
from IPython.display import Image

# %matplotlib inline
ox.config(log_console=True)
ox.__version__
# Out:
# '1.1.1'

# %%
# configure the inline image display
img_folder = "images"
extension = "png"
size = 240

# %%
tags = {"building": True}
tag1= {"building": True}
place="Piedmont, California, USA"

# %%
gdf = ox.geometries_from_place(place, tags)

# %%
gdf.columns
# Out:
# Index(['ele', 'gnis:county_id', 'gnis:created', 'gnis:feature_id',
#        'gnis:state_id', 'leisure', 'name', 'wikidata', 'geometry', 'addr:city',
#        'addr:housenumber', 'addr:postcode', 'addr:street', 'building', 'nodes',
#        'area', 'historic', 'opening_hours', 'phone', 'shop', 'website',
#        'amenity', 'atm', 'brand', 'brand:wikidata', 'brand:wikipedia',
#        'building:levels', 'operator', 'house', 'addr:state', 'religion',
#        'tourism', 'denomination', 'gnis:county_name', 'gnis:import_uuid',
#        'gnis:reviewed', 'source', 'ways', 'type'],
#       dtype='object')

# %%
gdf
# Out:
#                         addr:postcode  ...      reservoir
# element_type osmid                     ...
# node         3390717619         75116  ...            NaN
#              3980268306           NaN  ...            NaN
#              3985131776           NaN  ...            NaN
# way          68991249             NaN  ...            NaN
#              68991260           75008  ...            NaN
# ...                               ...  ...            ...
# relation     1261429              NaN  ...            NaN
#              1261430              NaN  ...            NaN
#              1668384              NaN  ...            NaN
#              2410509              NaN  ...            NaN
#              4024376              NaN  ...  water_storage
#
# [2091 rows x 146 columns]

# %%
img_folder='images';extension='png'
size=600
gdf_proj = ox.project_gdf(gdf)
fp = f"./{img_folder}/piedmont_bldgs.{extension}"
fig, ax = ox.plot_footprints(gdf_proj, filepath=fp, dpi=400, save=True, show=False, close=True)
Image(fp, height=size, width=size)

# %%
point = (48.873446, 2.294255)
dist = 612
gdf = ox.geometries_from_point(point, tags, dist=dist)
gdf_proj = ox.project_gdf(gdf)
bbox = ox.utils_geo.bbox_from_point(point=point, dist=dist, project_utm=True)
fp = f"./{img_folder}/paris_bldgs.{extension}"
fig, ax = ox.plot_footprints(
    gdf_proj,
    bbox=bbox,
    color="w",
    filepath=fp,
    dpi=90,
    save=True,
    show=False,
    close=True,
)
Image(fp, height=size, width=size)

# %%
gdf.columns
# Out:
# Index(['addr:postcode', 'amenity', 'operator', 'source', 'geometry', 'atm',
#        'name', 'opening_hours', 'phone', 'wheelchair',
#        ...
#        'station', 'subway', 'tunnel', 'building:levels:underground', 'fixme',
#        'ways', 'type', 'payment:cash', 'payment:credit_cards', 'reservoir'],
#       dtype='object', length=146)

# %%
gdf['building:levels'].shape, gdf.shape
# Out:
# ((2091,), (2091, 146))

# %%
gdf['building:levels'].isnull().values.all(), gdf['building:levels'].isnull().sum()
# Out:
# (False, 879)

# %%
gdf['building:levels:underground'].isnull().values.all(), gdf['building:levels:underground'].isnull().sum()
# Out:
# (False, 2088)

# %%
gdf['building:levels']=
# Out:
# dtype('O')

# %%
# get one color for each node, by elevation, then plot the network
nc = ox.plot.get_node_colors_by_attr(gdf, "building:levels", cmap="plasma")
fig, ax = ox.plot_graph(gdf, node_color=nc, node_size=5, edge_color="#333333", bgcolor="k")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-093a004892b7> in <module>()
#       1 # get one color for each node, by elevation, then plot the network
# ----> 2 nc = ox.plot.get_node_colors_by_attr(gdf, "building:levels", cmap="plasma")
#       3 fig, ax = ox.plot_graph(gdf, node_color=nc, node_size=5, edge_color="#333333", bgcolor="k")
#
# /usr/local/lib/python3.7/dist-packages/osmnx/plot.py in get_node_colors_by_attr(G, attr, num_bins, cmap, start, stop, na_color, equal_size)
#      83         series labels are node IDs and values are colors
#      84     """
# ---> 85     vals = pd.Series(nx.get_node_attributes(G, attr))
#      86     return _get_colors_by_value(vals, num_bins, cmap, start, stop, na_color, equal_size)
#      87
#
# /usr/local/lib/python3.7/dist-packages/networkx/classes/function.py in get_node_attributes(G, name)
#     714     'red'
# ...

# %%
point = (18.522240, -72.347607)
dist = 1612
gdf = ox.geometries_from_point(point, tags, dist=dist)
gdf_proj = ox.project_gdf(gdf)
bbox = ox.utils_geo.bbox_from_point(point=point, dist=dist, project_utm=True)
fp = f"./{img_folder}/paris_bldgs.{extension}"
fig, ax = ox.plot_footprints(
    gdf_proj,
    bbox=bbox,
    color="w",
    filepath=fp,
    dpi=190,
    save=True,
    show=False,
    close=True,
)
Image(fp, height=size, width=size)

# %%
gdf['building:levels']
# Out:
# element_type  osmid
# node          615029215     NaN
#               1123561905    NaN
#               1123561934    NaN
#               1384942396    NaN
#               1384975171    NaN
#                            ...
# relation      386797        NaN
#               2001860       NaN
#               5670198       NaN
#               6754310       NaN
#               6796989       NaN
# Name: building:levels, Length: 37663, dtype: object

# %%
gdf['building:levels'].isnull().values.all(), gdf['building:levels'].isnull().sum()
# Out:
# (False, 37636)

# %%
nc = ox.plot.get_node_colors_by_attr(gdf, "elevation", cmap="plasma")
fig, ax = ox.plot_graph(gdf, node_color=nc, node_size=5, edge_color="#333333", bgcolor="k")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-9d39d9cc89d7> in <module>()
# ----> 1 nc = ox.plot.get_node_colors_by_attr(gdf, "elevation", cmap="plasma")
#       2 fig, ax = ox.plot_graph(gdf, node_color=nc, node_size=5, edge_color="#333333", bgcolor="k")
#
# /usr/local/lib/python3.7/dist-packages/osmnx/plot.py in get_node_colors_by_attr(G, attr, num_bins, cmap, start, stop, na_color, equal_size)
#      83         series labels are node IDs and values are colors
#      84     """
# ---> 85     vals = pd.Series(nx.get_node_attributes(G, attr))
#      86     return _get_colors_by_value(vals, num_bins, cmap, start, stop, na_color, equal_size)
#      87
#
# /usr/local/lib/python3.7/dist-packages/networkx/classes/function.py in get_node_attributes(G, name)
#     714     'red'
#     715     """
# ...
